# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("C:\\Users\\saifi\\Downloads\\HR Data.xlsx")
df
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %% [markdown]
# # DataInfoGathering

# %%
# info
# shape
# min
# max
# count
# describe
# mean
# median
# std
# head
# tail

# %%
df.info
# Out:
# <bound method DataFrame.info of      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.shape
# Out:
# (1470, 39)

# %%
df.min()
# Out:
# Attrition                                            No
# Business Travel                              Non-Travel
# CF_age band                                     25 - 34
# CF_attrition label                    Current Employees
# Department                                           HR
# Education Field                         Human Resources
# emp no                                          STAFF-1
# Employee Number                                       1
# Gender                                           Female
# Job Role                      Healthcare Representative
# Marital Status                                 Divorced
# Over Time                                            No
# Over18                                                Y
# Training Times Last Year                              0
# Age                                                  18
# CF_current Employee                                   0
# Daily Rate                                          102
# ...

# %%
df.max()
# Out:
# Attrition                                      Yes
# Business Travel                      Travel_Rarely
# CF_age band                               Under 25
# CF_attrition label                    Ex-Employees
# Department                                   Sales
# Education Field                   Technical Degree
# emp no                                   STAFF-999
# Employee Number                               2068
# Gender                                        Male
# Job Role                      Sales Representative
# Marital Status                              Single
# Over Time                                      Yes
# Over18                                           Y
# Training Times Last Year                         6
# Age                                             60
# CF_current Employee                              1
# Daily Rate                                    1499
# Distance From Home                              29
# ...

# %%
df.count()
# Out:
# Attrition                     1470
# Business Travel               1470
# CF_age band                   1470
# CF_attrition label            1470
# Department                    1470
# Education Field               1470
# emp no                        1470
# Employee Number               1470
# Gender                        1470
# Job Role                      1470
# Marital Status                1470
# Over Time                     1470
# Over18                        1470
# Training Times Last Year      1470
# Age                           1470
# CF_current Employee           1470
# Daily Rate                    1470
# Distance From Home            1470
# Education                     1470
# Employee Count                1470
# Environment Satisfaction      1470
# Hourly Rate                   1470
# Job Involvement               1470
# Job Level                     1470
# Job Satisfaction              1470
# Monthly Income                1470
# Monthly Rate                  1470
# ...

# %%
df.describe()
# Out:
#        Employee Number  Training Times Last Year          Age  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.799320    36.923810
# std         602.024335                  1.289271     9.135373
# min           1.000000                  0.000000    18.000000
# 25%         491.250000                  2.000000    30.000000
# 50%        1020.500000                  3.000000    36.000000
# 75%        1555.750000                  3.000000    43.000000
# max        2068.000000                  6.000000    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# std               0.367863   403.509100            8.106864             0.0
# min               0.000000   102.000000            1.000000             1.0
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Employee Number                1024.865306
# Training Times Last Year          2.799320
# Age                              36.923810
# CF_current Employee               0.838776
# Daily Rate                      802.485714
# Distance From Home                9.192517
# Employee Count                    1.000000
# Environment Satisfaction          2.721769
# Hourly Rate                      65.891156
# Job Involvement                   2.729932
# Job Level                         2.063946
# Job Satisfaction                  2.728571
# Monthly Income                 6502.931293
# Monthly Rate                  14313.103401
# Num Companies Worked              2.693197
# Percent Salary Hike              15.209524
# Performance Rating                3.153741
# Relationship Satisfaction         2.712245
# Standard Hours                   80.000000
# Stock Option Level                0.793878
# Total Working Years              11.279592
# Work Life Balance                 2.761224
# ...

# %%
df.median(numeric_only=True)
# Out:
# Employee Number                1020.5
# Training Times Last Year          3.0
# Age                              36.0
# CF_current Employee               1.0
# Daily Rate                      802.0
# Distance From Home                7.0
# Employee Count                    1.0
# Environment Satisfaction          3.0
# Hourly Rate                      66.0
# Job Involvement                   3.0
# Job Level                         2.0
# Job Satisfaction                  3.0
# Monthly Income                 4919.0
# Monthly Rate                  14235.5
# Num Companies Worked              2.0
# Percent Salary Hike              14.0
# Performance Rating                3.0
# Relationship Satisfaction         3.0
# Standard Hours                   80.0
# Stock Option Level                1.0
# Total Working Years              10.0
# Work Life Balance                 3.0
# Years At Company                  5.0
# Years In Current Role             3.0
# Years Since Last Promotion        1.0
# ...

# %%
df.std(numeric_only=True)
# Out:
# Employee Number               6.020243e+02
# Training Times Last Year      1.289271e+00
# Age                           9.135373e+00
# CF_current Employee           3.678630e-01
# Daily Rate                    4.035091e+02
# Distance From Home            8.106864e+00
# Employee Count                1.110601e-16
# Environment Satisfaction      1.093082e+00
# Hourly Rate                   2.032943e+01
# Job Involvement               7.115611e-01
# Job Level                     1.106940e+00
# Job Satisfaction              1.102846e+00
# Monthly Income                4.707957e+03
# Monthly Rate                  7.117786e+03
# Num Companies Worked          2.498009e+00
# Percent Salary Hike           3.659938e+00
# Performance Rating            3.608235e-01
# Relationship Satisfaction     1.081209e+00
# Standard Hours                0.000000e+00
# Stock Option Level            8.520767e-01
# Total Working Years           7.780782e+00
# Work Life Balance             7.064758e-01
# ...

# %%
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
df.tail()
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number Gender  \
# 1465  Technical Degree  STAFF-1905             1905   Male
# 1466     Life Sciences  STAFF-1868             1868   Male
# 1467             Other  STAFF-1667             1667   Male
# 1468     Life Sciences  STAFF-1878             1878   Male
# 1469     Life Sciences  STAFF-1702             1702   Male
#
#                   Job Role  ... Performance Rating Relationship Satisfaction  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Missing Values
# Rename
# Drop
# Duplicates

# %%
df.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# ...

# %%
df.rename(columns={'CF_attrition label':'Attrition Label'}, inplace=True)

# %%
df
# Out:
#      Attrition    Business Travel CF_age band    Attrition Label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.drop(columns=['Employee Count','Employee Number','Over18','Standard Hours'], inplace=True)

# %%
df.head(10)
# Out:
#   Attrition    Business Travel CF_age band    Attrition Label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 5        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 6        No      Travel_Rarely     Over 55  Current Employees        R&D
# 7        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 8        No  Travel_Frequently     35 - 44  Current Employees        R&D
# 9        No      Travel_Rarely     35 - 44  Current Employees        R&D
#
#   Education Field    emp no  Gender                   Job Role Marital Status  \
# 0   Life Sciences   STAFF-1  Female            Sales Executive         Single
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Outlier Detection

# %%
# Scatter Plot
# Box Plot
# Reg Plot 
# IQR Method
# Heat Map
# Z score

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='Age', y='Years At Company', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Years At Company'>

# %%
sns.scatterplot(x='Total Working Years',y='Monthly Income',   data=df)
# Out:
# <Axes: xlabel='Total Working Years', ylabel='Monthly Income'>

# %%
sns.scatterplot(x='Monthly Income', y='Total Working Years', data=df)
# Out:
# <Axes: xlabel='Monthly Income', ylabel='Total Working Years'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(y='Age', color='r', data=df)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(y='Total Working Years', color='g', data=df)
# Out:
# <Axes: ylabel='Total Working Years'>

# %%
sns.boxplot(y='Years At Company', color='b', data=df)
# Out:
# <Axes: ylabel='Years At Company'>

# %% [markdown]
# # Reg Plot

# %%
sns.regplot(x='Age', y='Total Working Years', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Total Working Years'>

# %%
sns.regplot(x='Age', y='Years At Company', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Years At Company'>

# %%
sns.regplot(x='Total Working Years', y='Years At Company', data=df)
# Out:
# <Axes: xlabel='Total Working Years', ylabel='Years At Company'>

# %% [markdown]
# # IQR Method

# %%
percentile25 = df['Years At Company'].quantile(0.25)
percentile75 = df['Years At Company'].quantile(0.75)

# %%
print("75th quartile: ",percentile75)
print("25th quartile: ",percentile25)
# Out:
# 75th quartile:  9.0
# 25th quartile:  3.0

# %%
iqr = percentile75 - percentile25
print ("IQR: ",iqr)
# Out:
# IQR:  6.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 18.0
# Lower limit -6.0

# %%
df[df['Years At Company'] > upper_limit]
# Out:
#      Attrition    Business Travel CF_age band    Attrition Label Department  \
# 18          No      Travel_Rarely     45 - 54  Current Employees      Sales
# 28          No      Travel_Rarely     35 - 44  Current Employees        R&D
# 45         Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 62          No      Travel_Rarely     45 - 54  Current Employees        R&D
# 63          No      Travel_Rarely     Over 55  Current Employees      Sales
# ...        ...                ...         ...                ...        ...
# 1358        No         Non-Travel     45 - 54  Current Employees        R&D
# 1385        No      Travel_Rarely     Over 55  Current Employees      Sales
# 1395        No      Travel_Rarely     35 - 44  Current Employees         HR
# 1407       Yes      Travel_Rarely     45 - 54       Ex-Employees        R&D
# 1413       Yes  Travel_Frequently     45 - 54       Ex-Employees      Sales
#
# ...

# %%
df[df['Years At Company'] > upper_limit].count()
# Out:
# Attrition                     104
# Business Travel               104
# CF_age band                   104
# Attrition Label               104
# Department                    104
# Education Field               104
# emp no                        104
# Gender                        104
# Job Role                      104
# Marital Status                104
# Over Time                     104
# Training Times Last Year      104
# Age                           104
# CF_current Employee           104
# Daily Rate                    104
# Distance From Home            104
# Education                     104
# Environment Satisfaction      104
# Hourly Rate                   104
# Job Involvement               104
# Job Level                     104
# Job Satisfaction              104
# Monthly Income                104
# Monthly Rate                  104
# Num Companies Worked          104
# Percent Salary Hike           104
# Performance Rating            104
# ...

# %%
percentile25 = df['Monthly Income'].quantile(0.25)
percentile75 = df['Monthly Income'].quantile(0.75)

# %%
print("75th quartile: ",percentile75)
print("25th quartile: ",percentile25)
# Out:
# 75th quartile:  8379.0
# 25th quartile:  2911.0

# %%
iqr = percentile75 - percentile25
print ("IQR: ",iqr)
# Out:
# IQR:  5468.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 16581.0
# Lower limit -5291.0

# %%
percentile25 = df['Total Working Years'].quantile(0.25)
percentile75 = df['Total Working Years'].quantile(0.75)

# %%
print("75th quartile: ",percentile75)
print("25th quartile: ",percentile25)
# Out:
# 75th quartile:  15.0
# 25th quartile:  6.0

# %%
iqr = percentile75 - percentile25
print ("IQR: ",iqr)
# Out:
# IQR:  9.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 28.5
# Lower limit -7.5

# %% [markdown]
# # Heat Map

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Z score

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(df['Total Working Years'])

plt.subplot(1,2,2)
sns.histplot(df['Years At Company'])
plt.show()

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
sns.histplot(df['Age'])

plt.subplot(1,2,2)
sns.histplot(df['Job Satisfaction'])

plt.show()

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
sns.histplot(df['Years In Current Role'])

plt.subplot(1,2,2)
sns.histplot(df['Years Since Last Promotion'])

plt.show()

# %% [markdown]
# # Comparing Z Score and Box Plot

# %%
new_df = df[df['Total Working Years'] < upper_limit]
new_df.shape
# Out:
# (1407, 35)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df['Total Working Years'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(data = df['Total Working Years'])

plt.subplot(2,2,3)
sns.histplot(new_df['Total Working Years'], kde=True)

plt.subplot(2,2,4)
sns.boxplot(data = new_df['Total Working Years'])

plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.histplot(df['Years At Company'], kde=True)

plt.subplot(2,2,2)
sns.boxplot(data = df['Years At Company'])

plt.subplot(2,2,3)
sns.histplot(new_df['Years At Company'], kde=True)

plt.subplot(2,2,4)
sns.boxplot(data = new_df['Years At Company'])

plt.show()

# %% [markdown]
# # Removing The Outliear

# %%
df_no_outliers = df[(df['Total Working Years'] >= lower_limit) & (df['Total Working Years'] <= upper_limit)]

print("Original DataFrame:\n", df)
print("\nDataFrame without outliers:\n", df_no_outliers)
# Out:
# Original DataFrame:
#       Attrition    Business Travel CF_age band    Attrition Label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df_no_outliers = df[(df['Years At Company'] >= lower_limit) & (df['Years At Company'] <= upper_limit)]

print("Original DataFrame:\n", df)
print("\nDataFrame without outliers:\n", df_no_outliers)
# Out:
# Original DataFrame:
#       Attrition    Business Travel CF_age band    Attrition Label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %% [markdown]
# # X and Y

# %%
X = df[['Age','Monthly Income','Total Working Years','Years At Company']]
Y = df['Performance Rating']

# %%
X = df.loc[:, ['Age','Monthly Income','Total Working Years','Years At Company']]
Y = df['Performance Rating']

# %%
X
# Out:
#       Age  Monthly Income  Total Working Years  Years At Company
# 0      41            5993                    8                 6
# 1      49            5130                   10                10
# 2      37            2090                    7                 0
# 3      33            2909                    8                 8
# 4      27            3468                    6                 2
# ...   ...             ...                  ...               ...
# 1465   34            2307                    5                 5
# 1466   29            2439                    1                 1
# 1467   35            4581                   13                11
# 1468   22            2472                    1                 1
# 1469   23            2275                    3                 3
#
# [1470 rows x 4 columns]

# %%
Y
# Out:
# 0       3
# 1       4
# 2       3
# 3       3
# 4       3
#        ..
# 1465    4
# 1466    4
# 1467    4
# 1468    4
# 1469    4
# Name: Performance Rating, Length: 1470, dtype: int64

# %% [markdown]
# # Train test split

# %%
# Train test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,Y, test_size = 0.25, random_state = 42)

# %%
X_train
# Out:
#       Age  Monthly Income  Total Working Years  Years At Company
# 1343   31            5238                    9                 5
# 1121   34           17007                   16                14
# 1048   40           10435                   18                18
# 1393   25            4907                    6                 5
# 527    32            5396                   10                10
# ...   ...             ...                  ...               ...
# 1130   34            5063                    8                 8
# 1294   24            4162                    5                 5
# 860    22            2853                    1                 0
# 1459   46            8926                   13                 9
# 1126   38            5321                   10                 8
#
# [1102 rows x 4 columns]

# %%
X_test
# Out:
#       Age  Monthly Income  Total Working Years  Years At Company
# 1041   48            2367                   10                 8
# 184    53            4450                    5                 4
# 1222   33            4320                    5                 5
# 67     45            9724                   25                 1
# 220    36            5914                   16                13
# ...   ...             ...                  ...               ...
# 571    26            4364                    5                 2
# 1163   39            3902                    7                 2
# 243    40            3319                    9                 9
# 1411   28            2561                    8                 0
# 1370   36            6842                   13                 5
#
# [368 rows x 4 columns]

# %%
y_train
# Out:
# 1343    4
# 1121    3
# 1048    3
# 1393    4
# 527     3
#        ..
# 1130    3
# 1294    3
# 860     3
# 1459    4
# 1126    3
# Name: Performance Rating, Length: 1102, dtype: int64

# %%
y_test
# Out:
# 1041    3
# 184     3
# 1222    3
# 67      3
# 220     3
#        ..
# 571     3
# 1163    3
# 243     3
# 1411    3
# 1370    4
# Name: Performance Rating, Length: 368, dtype: int64

# %% [markdown]
# # Standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_test
# Out:
# array([[ 1.21642361, -0.87142787, -0.14374085,  0.17005187],
#        [ 1.75913569, -0.42746713, -0.78246026, -0.48289991],
#        [-0.41171261, -0.45517471, -0.78246026, -0.31966196],
#        ...,
#        [ 0.3480843 , -0.6685231 , -0.27148473,  0.33328981],
#        [-0.95442468, -0.83007963, -0.39922861, -1.13585168],
#        [-0.08608536,  0.08235241,  0.2394908 , -0.31966196]])

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.21642361, -0.87142787, -0.14374085,  0.17005187],
#        [ 1.75913569, -0.42746713, -0.78246026, -0.48289991],
#        [-0.41171261, -0.45517471, -0.78246026, -0.31966196],
#        ...,
#        [ 0.3480843 , -0.6685231 , -0.27148473,  0.33328981],
#        [-0.95442468, -0.83007963, -0.39922861, -1.13585168],
#        [-0.08608536,  0.08235241,  0.2394908 , -0.31966196]])

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # scaling of the data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # model selection and building

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
# LinearRegression()
regression.fit(X_train,y_train)
y_pred = regression.predict(X_test)
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# -0.021836060027285775

# %% [markdown]
# # model training

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # prediction

# %%
y_pred = regression.predict(X_test)

# %%
# prediciton result
y_pred
# Out:
# array([3.17650322, 3.1389363 , 3.14646924, 3.2169558 , 3.18467983,
#        3.16998954, 3.15156221, 3.17031843, 3.19278157, 3.14203029,
#        3.13921063, 3.1826158 , 3.15823381, 3.18166338, 3.14979448,
#        3.13055379, 3.17572506, 3.21146432, 3.11357763, 3.23803772,
#        3.15795985, 3.21551857, 3.1642465 , 3.14891148, 3.16743764,
#        3.12621637, 3.14481708, 3.16519358, 3.17785818, 3.17144107,
#        3.18762076, 3.15442421, 3.15691817, 3.16040776, 3.18919676,
#        3.1547875 , 3.16960567, 3.16190022, 3.14140711, 3.15798214,
#        3.15018182, 3.15037456, 3.19842101, 3.17325689, 3.13905043,
#        3.17764848, 3.13409966, 3.14740528, 3.19370471, 3.15088197,
#        3.16722159, 3.14930003, 3.12052529, 3.15555654, 3.15150093,
#        3.16573155, 3.20469598, 3.18969985, 3.16076389, 3.16162236,
#        3.13803515, 3.15296487, 3.15610501, 3.18719104, 3.19910191,
#        3.15551212, 3.14924826, 3.12788845, 3.15492607, 3.15831715,
# ...

# %% [markdown]
# # R2 score/Accuracy

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# -0.021836060027285775

# %%
# Adjusted R2
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# -0.03309596151518979
